# %% [markdown]
# #Д/з по Байесовским методам
#
# Вам предлагается выяснить, какое распределение лучше использовать в наивном байесовском классификаторе в зависимости от вида признаков.
#
# Загрузите датасеты digits и breast_cancer из sklearn.datasets. Выведите несколько строчек из обучающих выборок и посмотрите на признаки. С помощью sklearn.cross_validation.cross_val_score c настройками по умолчанию и вызова метода mean() у возвращаемого этой функцией numpy.ndarray, сравните качество работы наивных байесовских классификаторов на этих двух датасетах. Для сравнения предлагается использовать BernoulliNB, MultinomialNB и GaussianNB. Насколько полученные результаты согласуются с рекомендациями из лекций?
#
# Два датасета, конечно, еще не повод делать далеко идущие выводы, но при желании вы можете продолжить исследование на других выборках (например, из UCI репозитория).
#
# Для сдачи задания, ответьте на приведенные ниже вопросы.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import cross_val_score
from sklearn.datasets import load_digits, load_breast_cancer
from sklearn.metrics import mean_squared_error
from sklearn.naive_bayes import BernoulliNB, MultinomialNB, GaussianNB

# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ##Digits

# %%
X, y = load_digits(return_X_y=True)
# первая строка признаков
X[0,:]
# Out:
# array([ 0.,  0.,  5., 13.,  9.,  1.,  0.,  0.,  0.,  0., 13., 15., 10.,
#        15.,  5.,  0.,  0.,  3., 15.,  2.,  0., 11.,  8.,  0.,  0.,  4.,
#        12.,  0.,  0.,  8.,  8.,  0.,  0.,  5.,  8.,  0.,  0.,  9.,  8.,
#         0.,  0.,  4., 11.,  0.,  1., 12.,  7.,  0.,  0.,  2., 14.,  5.,
#        10., 12.,  0.,  0.,  0.,  0.,  6., 13., 10.,  0.,  0.,  0.])

# %%
names = ['BernoulliNB', 'MultinomialNB', 'GaussianNB']
classifiers = [BernoulliNB(), 
               MultinomialNB(), 
               GaussianNB()]

scores_digits = []
for n_clf, clf in zip(names, classifiers):
  NB_model = cross_val_score(clf, X, y=y)
  scores_digits.append(NB_model.mean())
  print(f'metric for {n_clf} is: {NB_model.mean()}')
# Out:
# metric for BernoulliNB is: 0.8241736304549674
# metric for MultinomialNB is: 0.8703497369235531
# metric for GaussianNB is: 0.8069281956050759

# %% [markdown]
# ##Breast_cancer

# %%
X, y = load_breast_cancer(return_X_y=True)
# первая строка признаков
X[0,:]
# Out:
# array([1.799e+01, 1.038e+01, 1.228e+02, 1.001e+03, 1.184e-01, 2.776e-01,
#        3.001e-01, 1.471e-01, 2.419e-01, 7.871e-02, 1.095e+00, 9.053e-01,
#        8.589e+00, 1.534e+02, 6.399e-03, 4.904e-02, 5.373e-02, 1.587e-02,
#        3.003e-02, 6.193e-03, 2.538e+01, 1.733e+01, 1.846e+02, 2.019e+03,
#        1.622e-01, 6.656e-01, 7.119e-01, 2.654e-01, 4.601e-01, 1.189e-01])

# %%
names = ['BernoulliNB', 'MultinomialNB', 'GaussianNB']
classifiers = [BernoulliNB(), 
               MultinomialNB(), 
               GaussianNB()]

scores_cancer = []
for n_clf, clf in zip(names, classifiers):
  NB_model = cross_val_score(clf, X, y=y)
  scores_cancer.append(NB_model.mean())
  print(f'metric for {n_clf} is: {NB_model.mean()}')
# Out:
# metric for BernoulliNB is: 0.6274181027790716
# metric for MultinomialNB is: 0.8963204471355379
# metric for GaussianNB is: 0.9385188635305075

# %% [markdown]
# ###Вопрос 1
#
# Каким получилось максимальное качество классификации на датасете breast_cancer?

# %%
with open('ans_1.txt', 'w') as fout:
  fout.write(str(max(scores_cancer)))

# %% [markdown]
# ###Вопрос 2
#
# Каким получилось максимальное качество классификации на датасете digits?

# %%
with open('ans_2.txt', 'w') as fout:
  fout.write(str(max(scores_digits)))

# %% [markdown]
# ###Вопрос 3
#
# Выберите верные утверждения и запишите их номера через пробел (в порядке возрастания номера):
#
# 1) На вещественных признаках лучше всего сработал наивный байесовский классификатор с распределением Бернулли
#
# 2) На вещественных признаках лучше всего сработал наивный байесовский классификатор с мультиномиальным распределением
#
# 3) Мультиномиальное распределение лучше показало себя на выборке с целыми неотрицательными значениями признаков
#
# 4) На вещественных признаках лучше всего сработало нормальное распределение
#
# Как отправить
# Когда работа будет готова, вы можете загрузить файлы для каждой части задания на вкладке 'Мои работы'.

# %%
Ans = [3, 4]

with open('ans_3.txt', 'w') as fout:
  fout.writelines(" ".join(map(str, Ans)))
